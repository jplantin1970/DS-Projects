# %% [markdown]
# <a href="https://colab.research.google.com/github/jplantin1970/DS-Projects/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
automobile = fetch_ucirepo(id=10)

# data (as pandas dataframes)
X = automobile.data.features
y = automobile.data.targets

# metadata
print(automobile.metadata)

# variable information
print(automobile.variables)
# Out:
# {'uci_id': 10, 'name': 'Automobile', 'repository_url': 'https://archive.ics.uci.edu/dataset/10/automobile', 'data_url': 'https://archive.ics.uci.edu/static/public/10/data.csv', 'abstract': "From 1985 Ward's Automotive Yearbook", 'area': 'Other', 'tasks': ['Regression'], 'characteristics': ['Multivariate'], 'num_instances': 205, 'num_features': 25, 'feature_types': ['Categorical', 'Integer', 'Real'], 'demographics': [], 'target_col': ['symboling'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 1985, 'last_updated': 'Thu Aug 10 2023', 'dataset_doi': '10.24432/C5B01C', 'creators': ['Jeffrey Schlimmer'], 'intro_paper': None, 'additional_info': {'summary': 'This data set consists of three types of entities: (a) the specification of an auto in terms of various characteristics, (b) its assigned insurance risk rating, (c) its normalized losses in use as compared to other cars.  The second rating corresponds to the degree to which 
# ...

# %%
# Import library package
import numpy as np
import pandas as pd

# %%
automobile = pd.read_csv('https://archive.ics.uci.edu/static/public/10/data.csv')

# %%
automobile.head()
# Out:
#    normalized-losses         make fuel-type aspiration  num-of-doors  \
# 0                NaN  alfa-romero       gas        std           2.0
# 1                NaN  alfa-romero       gas        std           2.0
# 2                NaN  alfa-romero       gas        std           2.0
# 3              164.0         audi       gas        std           4.0
# 4              164.0         audi       gas        std           4.0
#
#     body-style drive-wheels engine-location  wheel-base  length  ...  \
# 0  convertible          rwd           front        88.6   168.8  ...
# 1  convertible          rwd           front        88.6   168.8  ...
# 2    hatchback          rwd           front        94.5   171.2  ...
# 3        sedan          fwd           front        99.8   176.6  ...
# 4        sedan          4wd           front        99.4   176.6  ...
#
#    fuel-system  bore  stroke compression-ratio  horsepower  peak-rpm city-mpg  \
# ...

# %%
df = pd.DataFrame(automobile)

# %%
df_subset = df.loc[:,['num-of-cylinders', 'city-mpg', 'highway-mpg', 'price', 'body-style']]
df_subset
# Out:
#      num-of-cylinders  city-mpg  highway-mpg    price   body-style
# 0                   4        21           27  13495.0  convertible
# 1                   4        21           27  16500.0  convertible
# 2                   6        19           26  16500.0    hatchback
# 3                   4        24           30  13950.0        sedan
# 4                   5        18           22  17450.0        sedan
# ..                ...       ...          ...      ...          ...
# 200                 4        23           28  16845.0        sedan
# 201                 4        19           25  19045.0        sedan
# 202                 6        18           23  21485.0        sedan
# 203                 6        26           27  22470.0        sedan
# 204                 4        19           25  22625.0        sedan
#
# [205 rows x 5 columns]

# %%
df_subset.describe()
# Out:
#        num-of-cylinders    city-mpg  highway-mpg         price
# count        205.000000  205.000000   205.000000    201.000000
# mean           4.380488   25.219512    30.751220  13207.129353
# std            1.080854    6.542142     6.886443   7947.066342
# min            2.000000   13.000000    16.000000   5118.000000
# 25%            4.000000   19.000000    25.000000   7775.000000
# 50%            4.000000   24.000000    30.000000  10295.000000
# 75%            4.000000   30.000000    34.000000  16500.000000
# max           12.000000   49.000000    54.000000  45400.000000

# %%
df_subset.shape
# Out:
# (205, 5)

# %%
df_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   num-of-cylinders  205 non-null    int64
#  1   city-mpg          205 non-null    int64
#  2   highway-mpg       205 non-null    int64
#  3   price             201 non-null    float64
#  4   body-style        205 non-null    object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 8.1+ KB

# %%
df_subset.isnull().sum()
# Out:
# num-of-cylinders    0
# city-mpg            0
# highway-mpg         0
# price               4
# body-style          0
# dtype: int64

# %%
df_subset = df_subset.dropna(axis=0).reset_index(drop=True)

# %%
df_subset.isna().sum()
# Out:
# num-of-cylinders    0
# city-mpg            0
# highway-mpg         0
# price               0
# body-style          0
# dtype: int64

# %%
# Import Visualization package
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.pairplot(df_subset)

# %%
# Import math package
import math

# %%
# Take the logarithm of the feature 'price and insert it as the 3th column
df_subset.insert(3, "log_price", [math.log(price) for price in df_subset['price']])

# %%
df_subset.head()
# Out:
#    num-of-cylinders  city-mpg  highway-mpg  log_price    price   body-style
# 0                 4        21           27   9.510075  13495.0  convertible
# 1                 4        21           27   9.711116  16500.0  convertible
# 2                 6        19           26   9.711116  16500.0    hatchback
# 3                 4        24           30   9.543235  13950.0        sedan
# 4                 5        18           22   9.767095  17450.0        sedan

# %%
df_subset['num-of-cylinders'].unique()
# Out:
# array([ 4,  6,  5,  3, 12,  2,  8])

# %%
# Create boxplot to show price ditribution by 'num-of-cylinder'
sns.boxplot(x='num-of-cylinders', y= 'log_price', data = df_subset)
# Out:
# <Axes: xlabel='num-of-cylinders', ylabel='log_price'>

# %%
df_subset['body-style'].unique()
# Out:
# array(['convertible', 'hatchback', 'sedan', 'wagon', 'hardtop'],
#       dtype=object)

# %%
# Visualization of 'body-style' 'price' distribution
fig = plt.figure(figsize = (8,5))
body = df_subset['body-style']
log_price =df_subset['log_price']

# Creating the bar plot
plt.bar(body, log_price, color ='green', width =0.4)

plt.xlabel('Body Style')
plt.ylabel('Log Price')
plt.title("Body Style Price Distribution")
plt.show()

# %%
# Average price by Number of Cylinder
print(df_subset.groupby('num-of-cylinders')['price'].mean())
# Out:
# num-of-cylinders
# 2     13020.000000
# 3      5151.000000
# 4     10303.197452
# 5     22007.600000
# 6     23671.833333
# 8     38900.000000
# 12    36000.000000
# Name: price, dtype: float64

# %%
# Import package to build the model
import statsmodels.api as sample_data
from statsmodels.formula.api import ols
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# Construct a multiple linear regression
X,y = df_subset[['city-mpg','highway-mpg','num-of-cylinders']].values, df_subset[['log_price']].values
print('Features:', X[:5], '\nLabels:', y[:5], sep='\n')
# Out:
# Features:
# [[21 27  4]
#  [21 27  4]
#  [19 26  6]
#  [24 30  4]
#  [18 22  5]]
#
# Labels:
# [[9.51007453]
#  [9.71111566]
#  [9.71111566]
#  [9.54323479]
#  [9.76709493]]

# %%
# Split data 70% - 30% into training set and test set
X_train, X_test, y_train, y_test  = train_test_split(X, y, test_size= 0.30, random_state=0)
print('Training Set: %d rows\nTest Set: %d rows ' % (X_train.shape[0],X_test.shape[0]))
# Out:
# Training Set: 140 rows
# Test Set: 61 rows

# %%
# Fit a linear regression model on the training set
model  = LinearRegression().fit(X_train,y_train)
print(model)
# Out:
# LinearRegression()

# %%
# Evaluate the trained model
predictions = model.predict(X_test)
np.set_printoptions(suppress=True)
print('Predicted labels:', predictions[:10])
print('Actual labels:', y_test[:10])
# Out:
# Predicted labels: [[8.69787814]
#  [9.12719811]
#  [9.44802832]
#  [9.94372402]
#  [9.85139552]
#  [9.14567889]
#  [9.6831942 ]
#  [8.86637387]
#  [9.69906104]
#  [9.00718614]]
# Actual labels: [[8.74751095]
#  [9.27781209]
#  [9.53676227]
#  [9.51037089]
#  [9.66459564]
#  [9.04723303]
#  [9.63233478]
#  [8.58447794]
#  [9.95726526]
#  [8.84476883]]

# %%
# Calculate evaluation metrics: MSE, RMSE, R2
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, predictions)
print("MSE:" , mse)

rmse = np.sqrt(mse)
print("RMSE:", rmse)

r2 = r2_score(y_test, predictions)
print("R2:", r2)
# Out:
# MSE: 0.09730439633434056
# RMSE: 0.31193652613046224
# R2: 0.6715117764978782

# %%
fig=sns.regplot(x=y_test, y=predictions)
fig.set_xlabel('Actual Labels')
fig.set_ylabel('Predicted Labels')

plt.title('Vehicle Price Predictions')
plt.show()
