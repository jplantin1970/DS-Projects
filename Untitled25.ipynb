# %% [markdown]
# <a href="https://colab.research.google.com/github/jplantin1970/DS-Projects/blob/main/Untitled25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Build a classification Model using Decision Tree

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
csv_url ='https://raw.githubusercontent.com/MicrosoftDocs/mslearn-introduction-to-machine-learning/main/Data/ml-basics/diabetes.csv'
df = pd.read_csv(csv_url)
df.head()
# Out:
#    PatientID  Pregnancies  PlasmaGlucose  DiastolicBloodPressure  \
# 0    1354778            0            171                      80
# 1    1147438            8             92                      93
# 2    1640031            7            115                      47
# 3    1883350            9            103                      78
# 4    1424119            1             85                      59
#
#    TricepsThickness  SerumInsulin        BMI  DiabetesPedigree  Age  Diabetic
# 0                34            23  43.509726          1.213191   21         0
# 1                47            36  21.240576          0.158365   23         0
# 2                52            35  41.511523          0.079019   23         0
# 3                25           304  29.582192          1.282870   43         1
# 4                27            35  42.604536          0.549542   22         0

# %%
# Get Summary Statistics about thye dataset
df.describe()
# Out:
#           PatientID   Pregnancies  PlasmaGlucose  DiastolicBloodPressure  \
# count  1.500000e+04  15000.000000   15000.000000            15000.000000
# mean   1.502922e+06      3.224533     107.856867               71.220667
# std    2.892534e+05      3.391020      31.981975               16.758716
# min    1.000038e+06      0.000000      44.000000               24.000000
# 25%    1.252866e+06      0.000000      84.000000               58.000000
# 50%    1.505508e+06      2.000000     104.000000               72.000000
# 75%    1.755205e+06      6.000000     129.000000               85.000000
# max    1.999997e+06     14.000000     192.000000              117.000000
#
#        TricepsThickness  SerumInsulin           BMI  DiabetesPedigree  \
# count      15000.000000  15000.000000  15000.000000      15000.000000
# mean          28.814000    137.852133     31.509646          0.398968
# std           14.555716    133.068252      9.759000          0.377944
# ...

# %%
df.dtypes
# Out:
# PatientID                   int64
# Pregnancies                 int64
# PlasmaGlucose               int64
# DiastolicBloodPressure      int64
# TricepsThickness            int64
# SerumInsulin                int64
# BMI                       float64
# DiabetesPedigree          float64
# Age                         int64
# Diabetic                    int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# PatientID                 0
# Pregnancies               0
# PlasmaGlucose             0
# DiastolicBloodPressure    0
# TricepsThickness          0
# SerumInsulin              0
# BMI                       0
# DiabetesPedigree          0
# Age                       0
# Diabetic                  0
# dtype: int64

# %%
df.head()
# Out:
#    PatientID  Pregnancies  PlasmaGlucose  DiastolicBloodPressure  \
# 0    1354778            0            171                      80
# 1    1147438            8             92                      93
# 2    1640031            7            115                      47
# 3    1883350            9            103                      78
# 4    1424119            1             85                      59
#
#    TricepsThickness  SerumInsulin        BMI  DiabetesPedigree  Age  Diabetic
# 0                34            23  43.509726          1.213191   21         0
# 1                47            36  21.240576          0.158365   23         0
# 2                52            35  41.511523          0.079019   23         0
# 3                25           304  29.582192          1.282870   43         1
# 4                27            35  42.604536          0.549542   22         0

# %%
df['Diabetic'].value_counts(dropna = False)
# Out:
# 0    10000
# 1     5000
# Name: Diabetic, dtype: int64

# %%
 # 33.33% of the surveyed subjects were reported as Diabetic. Thus, we have a class imbalance.

# %%
# Features distribution by Diabetics
features= ['Pregnancies',	'PlasmaGlucose',	'DiastolicBloodPressure',	'TricepsThickness',	'SerumInsulin',	'BMI',	'DiabetesPedigree','Age']

for col in features:
  df.boxplot(column=col, by= 'Diabetic', figsize=(8,5) )
  plt.title(col)

# %%
# Load in sci-kit learn functions for constructing decision tree model
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# Package to display the splitof the tree
from sklearn.tree import plot_tree

from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
from sklearn.metrics import recall_score, precision_score, f1_score, accuracy_score
import sklearn.metrics as metrics

# %%
# Separate Features and labels
X, y = df[['Pregnancies', 'PlasmaGlucose', 'DiastolicBloodPressure', 'TricepsThickness', 'SerumInsulin', 'BMI', 'DiabetesPedigree', 'Age']].values, df[['Diabetic']].values
print('Features:', X[:3], '\nLabels:', y[:3], sep= '\n')
# Out:
# Features:
# [[0.00000000e+00 1.71000000e+02 8.00000000e+01 3.40000000e+01
#   2.30000000e+01 4.35097259e+01 1.21319135e+00 2.10000000e+01]
#  [8.00000000e+00 9.20000000e+01 9.30000000e+01 4.70000000e+01
#   3.60000000e+01 2.12405757e+01 1.58364981e-01 2.30000000e+01]
#  [7.00000000e+00 1.15000000e+02 4.70000000e+01 5.20000000e+01
#   3.50000000e+01 4.15115235e+01 7.90185680e-02 2.30000000e+01]]
#
# Labels:
# [[0]
#  [0]
#  [0]]

# %%
# Split dataset into training and testing
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.3, stratify=y, random_state=0)
print('Training cases: %d\nTest cases: %d' %(X_train.shape[0], X_test.shape[0]))
# Out:
# Training cases: 10500
# Test cases: 4500

# %%
# Instantiate the model
decision_tree=  DecisionTreeClassifier(random_state= 0)

# Fit the model to training data
clf= decision_tree.fit(X_train, y_train)

# Make predictions on test data
dt_pred = decision_tree.predict(X_test)

# %%
# Generate performance metrics

print("Accuracy:", "%.3f" % accuracy_score(y_test, dt_pred))
print("Precision:", "%.3f" % precision_score(y_test, dt_pred))
print("Recall:", "%.3f" % recall_score(y_test, dt_pred))
print("F1 Score:", "%.3f" % f1_score(y_test, dt_pred))
# Out:
# Accuracy: 0.906
# Precision: 0.857
# Recall: 0.861
# F1 Score: 0.859

# %%
# Calculate the values for each quadrant in the confusion matrix
cm = metrics.confusion_matrix(y_test, dt_pred, labels=clf.classes_)

# %%
# Generate the confusion matrix display

disp= metrics.ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=clf.classes_)
disp.plot()

# %%
X=df[['Pregnancies', 'PlasmaGlucose', 'DiastolicBloodPressure', 'TricepsThickness', 'SerumInsulin', 'BMI', 'DiabetesPedigree', 'Age']]

# %%
# Convert Numpy Array into  Pandas dataframe
X=pd.DataFrame(X)

# %%
# Plot the tree
plt.figure(figsize=(15,12))
plot_tree(decision_tree, max_depth=2, fontsize=14, feature_names= X.columns, class_names={0:'Non_Diabetics', 1:'Diabetics'}, filled=True);
plt.show()
